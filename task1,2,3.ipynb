# %% [markdown]
# <a href="https://colab.research.google.com/github/torpidasia/torpidasia/blob/main/task1%2C2%2C3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
initializeTurtle()
bgcolor("blue")
pensize(6)
color("white")
fillcolor("aqua")
begin_fill()
forward(100)
right(270)
forward(100)
right(270)
forward(100)
right(270)
forward(100)
end_fill()
# Out:
# Requirement already satisfied: ColabTurtlePlus in /usr/local/lib/python3.7/dist-packages (2.0.1)
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:blue;stroke:;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 400.0 300.0  L 500.0 300.0  L 500.0 200.0  L 400.0 200.0  L 400.0 300.0 " stroke-linecap="round" style="stroke:white;stroke-width:6" fill="aqua" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(0,400.0,300.0) translate(400.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:white;fill:aqua;stroke-width:1" />
# </g>
#       </svg>

# %%
# !pip3 install ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
initializeTurtle()
bgcolor("pink")
color("white")
pensize(5)
fillcolor("yellow")
begin_fill()
goto(100,100)
goto(-100,100)
goto(60,-30)
goto(-50,150)
right(90)
forward(197)
goto(100,100)
end_fill()
# Out:
# Requirement already satisfied: ColabTurtlePlus in /usr/local/lib/python3.7/dist-packages (2.0.1)
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:pink;stroke:;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 400.0 300.0  L 500.0 200.0  L 300.0 200.0  L 460.0 330.0  L 350.0 150.0  L 350.0 347.0  L 500.0 200.0 " stroke-linecap="round" style="stroke:white;stroke-width:5" fill="yellow" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(0,500.0,200.0) translate(500.0, 200.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:white;fill:yellow;stroke-width:1" />
# </g>
#       </svg>

# %%
# !pip3 install ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
initializeTurtle()
pencolor('white')
bgcolor('red')
pensize(2)
forward(150)
backward(150)
right(60)
forward(150)
backward(150)
right(60)
forward(150)
backward(150)
right(60)
forward(150)
backward(150)
right(60)
forward(150)
backward(150)
right(60)
forward(150)
backward(150)
right(60)

goto(0,0)
forward(150)
right(120)

forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)

goto(0,0)
forward(150)
right(120)

forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)


goto(0,0)
forward(130)
right(120)

forward(130)
right(60)
forward(130)
right(60)
forward(130)
right(60)
forward(130)
right(60)
forward(130)
right(60)
forward(130)
right(60)


goto(0,0)
forward(110)
right(120)

forward(110)
right(60)
forward(110)
right(60)
forward(110)
right(60)
forward(110)
right(60)
forward(110)
right(60)
forward(110)
right(60)


goto(0,0)
forward(90)
right(120)

forward(90)
right(60)
forward(90)
right(60)
forward(90)
right(60)
forward(90)
right(60)
forward(90)
right(60)
forward(90)
right(60)


goto(0,0)
forward(70)
right(120)

forward(70)
right(60)
forward(70)
right(60)
forward(70)
right(60)
forward(70)
right(60)
forward(70)
right(60)
forward(70)
right(60)


goto(0,0)
forward(50)
right(120)

forward(50)
right(60)
forward(50)
right(60)
forward(50)
right(60)
forward(50)
right(60)
forward(50)
right(60)
forward(50)
right(60)


goto(0,0)
forward(30)
right(120)

forward(30)
right(60)
forward(30)
right(60)
forward(30)
right(60)
forward(30)
right(60)
forward(30)
right(60)
forward(30)
right(60)


goto(0,0)
forward(10)
right(120)

forward(10)
right(60)
forward(10)
right(60)
forward(10)
right(60)
forward(10)
right(60)
forward(10)
right(60)
forward(10)
right(60)

goto(0,0)
forward(150)
right(120)

forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)
forward(150)
right(60)
# Out:
# Requirement already satisfied: ColabTurtlePlus in /usr/local/lib/python3.7/dist-packages (2.0.1)
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:red;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="550.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="550.0" y1="300.0" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="400.0" y1="300.0" x2="475.0" y2="429.904" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="475.0" y1="429.904" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="400.0" y1="300.0" x2="325.0" y2="429.904" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="325.0" y1="429.904" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="400.0" y1="300.0" x2="250.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="250.0" y1="300.0" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="400.0" y1="300.0" x2="325.0" y2="170.096" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="325.0" y1="170.096" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="400.0" y1="300.0" x2="475.0" y2="170.096" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="475.0" y1="170.096" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="400.0" y1="300.0" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="400.0" y1="300.0" x2="550.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="550.0" y1="300.0" x2="475.0" y2="429.904" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="475.0" y1="429.904" x2="325.0" y2="429.904" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="325.0" y1="429.904" x2="250.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="250.0" y1="300.0" x2="325.0" y2="170.096" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="325.0" y1="170.096" x2="475.0" y2="170.096" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="475.0" y1="170.096" x2="550.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="550.0" y1="300.0" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="400.0" y1="300.0" x2="325.0" y2="429.904" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="325.0" y1="429.904" x2="250.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="250.0" y1="300.0" x2="325.0" y2="170.096" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="325.0" y1="170.096" x2="475.0" y2="170.096" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="475.0" y1="170.096" x2="550.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="550.0" y1="300.0" x2="475.0" y2="429.904" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="475.0" y1="429.904" x2="325.0" y2="429.904" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="325.0" y1="429.904" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="400.0" y1="300.0" x2="335.0" y2="187.417" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="335.0" y1="187.417" x2="465.0" y2="187.417" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="465.0" y1="187.417" x2="530.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="530.0" y1="300.0" x2="465.0" y2="412.583" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="465.0" y1="412.583" x2="335.0" y2="412.583" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="335.0" y1="412.583" x2="270.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:2" /><line x1="270.0" y1="300.0" x2="335.0"  ...
